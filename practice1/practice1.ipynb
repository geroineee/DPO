# %% [markdown]
# ## Первый компутаттионал нотбук

# %% [markdown]
# ## Упражнение: вычисленеие числа pi методом Монте-Карло

# %% [markdown]
# # PI методом монте-карло

# %% [markdown]
# ## Формулы
# - площадь квадрата: $s = (2 r)^2$
# - площадь круга: $c = \pi r^2$
# - $c/s = (\pi r^2) / (4 r^2) = \pi / 4$
# - $\pi = 4 * c/s$

# %% [markdown]
# ![Дротики](https://avatars.mds.yandex.net/i?id=7d7f378c27bf67f22b82d3227281f238_sr-9068727-images-thumbs&n=13)

# %% [markdown]
# ### Импорт библиотек

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# Инициализация переменной с количествмо точек

# %%
num_points = 50000

# %% [markdown]
# ### Броски дротиков

# %%
points = []
hits = 0

for _ in range(num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x, y, "cyan"))
    else:
        points.append((x, y, "gray"))

# %% [markdown]
# ### Построение графика результатов

# %%
x , y, colors = zip(*points)

fig, ax = plt.subplots()
fig.set_size_inches(10.0, 10.0)

ax.scatter(x, y, c = colors)

fraction = hits / num_points

# %% [markdown]
# ## Полученный результат $\pi$:

# %%
print("π = ", fraction * 4)
# Out:
# π =  3.14048

# %% [markdown]
# ## Зависимости

# %%
# !python -m pip install pandas matplotlib
# !python -m pip install pandas matplotlib seaborn
# !python -m pip install ipywidgets

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
from itertools import cycle

# %% [markdown]
# ### метод Монте-Карло (код покруче)

# %%
def throw_darts(num_points):
    points = []
    hits = 0
    for _ in range(num_points):
        x, y = random.random(), random.random()
        if x*x + y*y < 1.0:
            hits += 1
            points.append((x, y, True))
        else:
            points.append((x, y, False))
    fraction = hits / num_points
    pi = 4 * fraction
    return pi, points


def create_plot(points):
    x, y, colors = zip(*points)
    pyplot.scatter(x, y, c=colors)


def experiment(num_points):
    pi, points = throw_darts(num_points)
    create_plot(points)
    print("approximation:", pi)

# %%
from matplotlib import pyplot
import random
from ipywidgets import interact, widgets

# %%
# !echo "Да я программист!"
# Out:
# "�� � �ணࠬ����!"

# %%
# !echo "Ну почти"
# Out:
# "�� ����"

# %% [markdown]
# ### Использование виджетов

# %%
interact(experiment, num_points=widgets.IntSlider(min=100, max=10000, step=100,
value=1000))
# Out:
# interactive(children=(IntSlider(value=1000, description='num_points', max=10000, min=100, step=100), Output())…
# <function __main__.experiment(num_points)>

# %%
from ipywidgets import interact

def f(x, y, s):
    return (x, y, s)

interact(f, x=True, y=1.0, s = "Hello!");
# Out:
# interactive(children=(Checkbox(value=True, description='x'), FloatSlider(value=1.0, description='y', max=3.0, …
